# %%
import graphix


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size

def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:20
#      17     colours, size = get_inputs()
#      18     draw_patches(colours, size)
# ---> 20 main()
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:18
#      16 def main():
#      17     colours, size = get_inputs()
# ---> 18     draw_patches(colours, size)
#
# NameError: name 'draw_patches' is not defined

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(X+50),int(Y+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            print(f"Debug: {colour_count}")
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:62
#      59     colours, size = get_inputs()
#      60     draw_patches(colours, size)
# ---> 62 main()
#      65 def draw_patch_window():
#      66     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:60
#      58 def main():
#      59     colours, size = get_inputs()
# ---> 60     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:29
#      27 for Y in range(0, window_size, 100):
#      28     for X in range(0, window_size, 100):
# ---> 29         colour_count = not colour_count
#      30         print(f"Debug: {colour_count}")
#      31         tl = Point(X,Y)
#
# UnboundLocalError: cannot access local variable 'colour_count' where it is not associated with a value

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(X+50),int(Y+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            print(f"Debug: {colour_count}")
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:30
#      28 for Y in range(0, window_size, 100):
#      29     for X in range(0, window_size, 100):
# ---> 30         colour_count = not colour_count
#      31         print(f"Debug: {colour_count}")
#      32         tl = Point(X,Y)
#
# UnboundLocalError: cannot access local variable 'colour_count' where it is not associated with a value

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(tl+50),int(br+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            print(f"Debug: {colour_count}")
            draw_rectangle(win, Point(200,200), Point(210,210), "yellow")
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:64
#      61     colours, size = get_inputs()
#      62     draw_patches(colours, size)
# ---> 64 main()
#      67 def draw_patch_window():
#      68     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      60 def main():
# ---> 61     colours, size = get_inputs()
#      62     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:48
#      47 def get_inputs():
# ---> 48     size = int(input("Please enter what size you'd like (5, 7, 9): "))
#      49     #colour_one = input("Colour 1: ")
#      50     colour_one = "blue"
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(tl+50),int(br+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            print(f"Debug: {colour_count}")
            draw_rectangle(win, Point(200,200), Point(210,210), "yellow")
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:64
#      61     colours, size = get_inputs()
#      62     draw_patches(colours, size)
# ---> 64 main()
#      67 def draw_patch_window():
#      68     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      60 def main():
# ---> 61     colours, size = get_inputs()
#      62     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:48
#      47 def get_inputs():
# ---> 48     size = int(input("Please enter what size you'd like (5, 7, 9): "))
#      49     #colour_one = input("Colour 1: ")
#      50     colour_one = "blue"
#
# ValueError: invalid literal for int() with base 10: 'j'

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(tl+50),int(br+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            print(f"Debug: {colour_count}")
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:30
#      28 for Y in range(0, window_size, 100):
#      29     for X in range(0, window_size, 100):
# ---> 30         colour_count = not colour_count
#      31         print(f"Debug: {colour_count}")
#      32         tl = Point(X,Y)
#
# UnboundLocalError: cannot access local variable 'colour_count' where it is not associated with a value

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(tl+50),int(br+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:62
#      59     colours, size = get_inputs()
#      60     draw_patches(colours, size)
# ---> 62 main()
#      65 def draw_patch_window():
#      66     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:60
#      58 def main():
#      59     colours, size = get_inputs()
# ---> 60     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:30
#      28 for Y in range(0, window_size, 100):
#      29     for X in range(0, window_size, 100):
# ---> 30         colour_count = not colour_count
#      31         tl = Point(X,Y)
#      32         br = Point(X + 100, Y + 100)
#
# UnboundLocalError: cannot access local variable 'colour_count' where it is not associated with a value

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(tl+50),int(br+50)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:39
#      37     patch_1(win, tl, br, current_colour)
#      38 elif Y < window_size - 100:
# ---> 39     patch_1(win, tl, br, current_colour)
#      40 else:
#      41     patch_plain(win, tl, br, current_colour)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:21
#      19 def patch_1(win, tl, br, current_colour):
#      20     draw_rectangle(win, tl, br, current_colour)
# ---> 21     message = Text(Point(int(tl+50),int(br+50)), "Hi!")
#      22     message.draw(win)
#
# TypeError: unsupported operand type(s) for +: 'Point' and 'int'

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(int(tl),int(br)), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:39
#      37     patch_1(win, tl, br, current_colour)
#      38 elif Y < window_size - 100:
# ---> 39     patch_1(win, tl, br, current_colour)
#      40 else:
#      41     patch_plain(win, tl, br, current_colour)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:21
#      19 def patch_1(win, tl, br, current_colour):
#      20     draw_rectangle(win, tl, br, current_colour)
# ---> 21     message = Text(Point(int(tl),int(br)), "Hi!")
#      22     message.draw(win)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'Point'

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(tl,br), "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# GraphixError                              Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:39
#      37     patch_1(win, tl, br, current_colour)
#      38 elif Y < window_size - 100:
# ---> 39     patch_1(win, tl, br, current_colour)
#      40 else:
#      41     patch_plain(win, tl, br, current_colour)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:21
#      19 def patch_1(win, tl, br, current_colour):
#      20     draw_rectangle(win, tl, br, current_colour)
# ---> 21     message = Text(Point(tl,br), "Hi!")
#      22     message.draw(win)
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:454, in Point.__init__(self, x, y)
#     452 """Inititialises the point with x and y coordinates."""
#     453 if not isinstance(x, int) or not isinstance(y, int):
# --> 454     raise GraphixError("Point coordinates must be integers")
#     455 GraphixObject.__init__(self, ["outline", "fill"])
#     456 self._x = x
#
# GraphixError: Point coordinates must be integers

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:61
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:39
#      37     patch_1(win, tl, br, current_colour)
#      38 elif Y < window_size - 100:
# ---> 39     patch_1(win, tl, br, current_colour)
#      40 else:
#      41     patch_plain(win, tl, br, current_colour)
#
# File /home/scarlettlarder/Course/programming/Course-Work/assign1/2276970.py:21
#      19 def patch_1(win, tl, br, current_colour):
#      20     draw_rectangle(win, tl, br, current_colour)
# ---> 21     message = Text(Point((br.x+10),(br+10)) ,  "Hi!")
#      22     message.draw(win)
#
# TypeError: unsupported operand type(s) for +: 'Point' and 'int'

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X < Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5
# Getting sent!
# Getting sent!

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    print("Getting sent!")
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    print(f"Debug: Colours,{colours} Size,{size}")
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: Colours,['blue', 'orange', 'red'] Size,5

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if X > 100:
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    patch_1(win, tl, br, current_colour)
                else:
                    print(f"Debug: X,{X} | Y,{Y}")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                if X > 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, current_colour)
                elif Y < window_size - 100:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, current_colour)
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: Cond 2
# Debug: X,200 | Y,0
# Debug: Cond 1
# Debug: X,300 | Y,0
# Debug: Cond 1
# Debug: X,400 | Y,0
# Debug: Cond 1
# Debug: X,200 | Y,100
# Debug: Cond 1
# Debug: X,300 | Y,100
# Debug: Cond 1
# Debug: X,400 | Y,100
# Debug: Cond 1
# Debug: X,300 | Y,200
# Debug: Cond 1
# Debug: X,400 | Y,200
# Debug: Cond 1
# Debug: X,400 | Y,300
# Debug: Cond 1

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                if X < 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, current_colour)
                elif Y > window_size - 100:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, current_colour)
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: Else
# Debug: X,200 | Y,0
# Debug: Else
# Debug: X,300 | Y,0
# Debug: Else
# Debug: X,400 | Y,0
# Debug: Else
# Debug: X,200 | Y,100
# Debug: Else
# Debug: X,300 | Y,100
# Debug: Else
# Debug: X,400 | Y,100
# Debug: Else
# Debug: X,300 | Y,200
# Debug: Else
# Debug: X,400 | Y,200
# Debug: Else
# Debug: X,400 | Y,300
# Debug: Else

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                if Y > 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 100:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, current_colour)
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: Else
# Debug: X,200 | Y,0
# Debug: Else
# Debug: X,300 | Y,0
# Debug: Else
# Debug: X,400 | Y,0
# Debug: Else
# Debug: X,200 | Y,100
# Debug: Else
# Debug: X,300 | Y,100
# Debug: Else
# Debug: X,400 | Y,100
# Debug: Else
# Debug: X,300 | Y,200
# Debug: Cond 1
# Debug: X,400 | Y,200
# Debug: Cond 1
# Debug: X,400 | Y,300
# Debug: Cond 1

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                if Y > 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, "red")
                elif X > window_size - 100:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, "blue")
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: Else
# Debug: X,200 | Y,0
# Debug: Else
# Debug: X,300 | Y,0
# Debug: Else
# Debug: X,400 | Y,0
# Debug: Else
# Debug: X,200 | Y,100
# Debug: Else
# Debug: X,300 | Y,100
# Debug: Else
# Debug: X,400 | Y,100
# Debug: Else
# Debug: X,300 | Y,200
# Debug: Cond 1
# Debug: X,400 | Y,200
# Debug: Cond 1
# Debug: X,400 | Y,300
# Debug: Cond 1

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                if Y < 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, "red")
                elif X > window_size - 100:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, "blue")
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: Cond 1
# Debug: X,200 | Y,0
# Debug: Cond 1
# Debug: X,300 | Y,0
# Debug: Cond 1
# Debug: X,400 | Y,0
# Debug: Cond 1
# Debug: X,200 | Y,100
# Debug: Else
# Debug: X,300 | Y,100
# Debug: Else
# Debug: X,400 | Y,100
# Debug: Else
# Debug: X,300 | Y,200
# Debug: Else
# Debug: X,400 | Y,200
# Debug: Else
# Debug: X,400 | Y,300
# Debug: Else

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                print(f"Debug: {window_size}")
                if Y < 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, "red")
                elif X > window_size - 100:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, "blue")
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,200 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,300 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,400 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,200 | Y,100
# Debug: 500
# Debug: Else
# Debug: X,300 | Y,100
# Debug: 500
# Debug: Else
# Debug: X,400 | Y,100
# Debug: 500
# Debug: Else
# Debug: X,300 | Y,200
# Debug: 500
# Debug: Else
# Debug: X,400 | Y,200
# Debug: 500
# Debug: Else
# Debug: X,400 | Y,300
# Debug: 500
# Debug: Else

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((br.x+10),(br.y+10)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                print(f"Debug: X,{X} | Y,{Y}")
                print(f"Debug: {window_size}")
                if Y < 100:
                    print("Debug: Cond 1")
                    patch_1(win, tl, br, "red")
                elif X > window_size - 200:
                    print("Debug: Cond 2")
                    patch_1(win, tl, br, "blue")
                else:
                    print("Debug: Else")
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Debug: X,100 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,200 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,300 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,400 | Y,0
# Debug: 500
# Debug: Cond 1
# Debug: X,200 | Y,100
# Debug: 500
# Debug: Else
# Debug: X,300 | Y,100
# Debug: 500
# Debug: Else
# Debug: X,400 | Y,100
# Debug: 500
# Debug: Cond 2
# Debug: X,300 | Y,200
# Debug: 500
# Debug: Else
# Debug: X,400 | Y,200
# Debug: 500
# Debug: Cond 2
# Debug: X,400 | Y,300
# Debug: 500
# Debug: Cond 2

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point((200,200),(200,200)) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# GraphixError                              Traceback (most recent call last)
# Cell In[1], line 61
#      58     colours, size = get_inputs()
#      59     draw_patches(colours, size)
# ---> 61 main()
#      64 def draw_patch_window():
#      65     win = Window("Patch Design",500,500)
#
# Cell In[1], line 59, in main()
#      57 def main():
#      58     colours, size = get_inputs()
# ---> 59     draw_patches(colours, size)
#
# Cell In[1], line 35, in draw_patches(colours, size)
#      33 current_colour = colours[1]
#      34 if Y < 100:
# ---> 35     patch_1(win, tl, br, current_colour)
#      36 elif X > window_size - 200:
#      37     patch_1(win, tl, br, current_colour)
#
# Cell In[1], line 20, in patch_1(win, tl, br, current_colour)
#      18 def patch_1(win, tl, br, current_colour):
#      19     draw_rectangle(win, tl, br, current_colour)
# ---> 20     message = Text(Point((200,200),(200,200)) ,  "Hi!")
#      21     message.draw(win)
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:454, in Point.__init__(self, x, y)
#     452 """Inititialises the point with x and y coordinates."""
#     453 if not isinstance(x, int) or not isinstance(y, int):
# --> 454     raise GraphixError("Point coordinates must be integers")
#     455 GraphixObject.__init__(self, ["outline", "fill"])
#     456 self._x = x
#
# GraphixError: Point coordinates must be integers

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(200,200) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(tl.x,tl.y) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(tl.x-10,tl.y) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    draw_rectangle(win, tl, br, current_colour)
    message = Text(Point(tl.x+50,tl.y+50) ,  "Hi!")
    message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for i in range(0,5,20):
        print(i)
        
        draw_rectangle(win, tl, br, current_colour)
        message = Text(Point(tl.x+50,tl.y+50), "Hi!")
        message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for i in range(0,100,20):
        print(i)
        
        draw_rectangle(win, tl, br, current_colour)
        message = Text(Point(tl.x+50,tl.y+50), "Hi!")
        message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# 0
# 20
# 40
# 60
# 80
# 0
# 20
# 40
# 60
# 80
# 0
# 20
# 40
# 60
# 80
# 0
# 20
# 40
# 60
# 80
# 0
# 20
# 40
# 60
# 80
# 0
# 20
# 40
# 60
# 80
# 0
# 20
# 40
# 60
# 80

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for i in range(0,100,20):
        draw_rectangle(win, Point(tl.x+i,tl.y+i), br, current_colour)
        message = Text(Point(tl.x+i,tl.y+i), "Hi!")
        message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for i in range(0,100,20):
        draw_rectangle(win, Point(tl.x+i,tl.y+i), br, current_colour)
        message = Text(Point(tl.x+i,tl.y+i), "Hi!")
        message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for i in range(4):
        for i in range(0,100,20):
            draw_rectangle(win, Point(tl.x+i,tl.y+i), br, current_colour)
            message = Text(Point(tl.x+i,tl.y+i), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for i in range(4):
        for i in range(0,100,20):
            draw_rectangle(win, Point(tl.x+i,tl.y+i), br, current_colour)
            message = Text(Point(tl.x+i,tl.y+i), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+x,tl.y+y), br, current_colour)
            message = Text(Point(tl.x+x,tl.y+y), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# Cell In[1], line 61, in main()
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# Cell In[1], line 37, in draw_patches(colours, size)
#      35 current_colour = colours[1]
#      36 if Y < 100:
# ---> 37     patch_1(win, tl, br, current_colour)
#      38 elif X > window_size - 200:
#      39     patch_1(win, tl, br, current_colour)
#
# Cell In[1], line 21, in patch_1(win, tl, br, current_colour)
#      19 for Y in range(0,100,20):
#      20     for X in range(0,100,20):
# ---> 21         draw_rectangle(win, Point(tl.x+x,tl.y+y), br, current_colour)
#      22         message = Text(Point(tl.x+x,tl.y+y), "Hi!")
#      23         message.draw(win)
#
# NameError: name 'x' is not defined

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+X,tl.y+Y), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+X,tl.y+Y), "Hi!", 5)
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# Cell In[1], line 61, in main()
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# Cell In[1], line 37, in draw_patches(colours, size)
#      35 current_colour = colours[1]
#      36 if Y < 100:
# ---> 37     patch_1(win, tl, br, current_colour)
#      38 elif X > window_size - 200:
#      39     patch_1(win, tl, br, current_colour)
#
# Cell In[1], line 22, in patch_1(win, tl, br, current_colour)
#      20 for X in range(0,100,20):
#      21     draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
# ---> 22     message = Text(Point(tl.x+X,tl.y+Y), "Hi!", 5)
#      23     message.draw(win)
#
# TypeError: Text.__init__() takes 3 positional arguments but 4 were given

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+X,tl.y+Y), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+(X-5),tl.y+(Y-5)), br, current_colour)
            message = Text(Point(tl.x+(X-5),tl.y+(Y-5)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y-5), br, current_colour)
            message = Text(Point(tl.x+(X-5),tl.y+(Y-5)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X-5),tl.y+(Y-5)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X),tl.y+(Y-5)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X),tl.y+(Y)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+2.5),tl.y+(Y+2.5)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# GraphixError                              Traceback (most recent call last)
# Cell In[7], line 63
#      60     colours, size = get_inputs()
#      61     draw_patches(colours, size)
# ---> 63 main()
#      66 def draw_patch_window():
#      67     win = Window("Patch Design",500,500)
#
# Cell In[7], line 61, in main()
#      59 def main():
#      60     colours, size = get_inputs()
# ---> 61     draw_patches(colours, size)
#
# Cell In[7], line 37, in draw_patches(colours, size)
#      35 current_colour = colours[1]
#      36 if Y < 100:
# ---> 37     patch_1(win, tl, br, current_colour)
#      38 elif X > window_size - 200:
#      39     patch_1(win, tl, br, current_colour)
#
# Cell In[7], line 22, in patch_1(win, tl, br, current_colour)
#      20 for X in range(0,100,20):
#      21     draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
# ---> 22     message = Text(Point(tl.x+(X+2.5),tl.y+(Y+2.5)), "Hi!")
#      23     message.draw(win)
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:454, in Point.__init__(self, x, y)
#     452 """Inititialises the point with x and y coordinates."""
#     453 if not isinstance(x, int) or not isinstance(y, int):
# --> 454     raise GraphixError("Point coordinates must be integers")
#     455 GraphixObject.__init__(self, ["outline", "fill"])
#     456 self._x = x
#
# GraphixError: Point coordinates must be integers

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+2),tl.y+(Y+2)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+3),tl.y+(Y+3)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+3),tl.y+(Y+3)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+4),tl.y+(Y+4)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+2),tl.y+(Y+2)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+3),tl.y+(Y+3)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X-5),tl.y+(Y-5)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X-3),tl.y+(Y-3)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X-2),tl.y+(Y-2)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X),tl.y+(Y)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X),tl.y+(Y)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X-2),tl.y+(Y)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+2),tl.y+(Y)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+4),tl.y+(Y)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+5),tl.y+(Y)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                pass


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[0]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[1]
                else:
                    current_colour = colours[2]
                patch_plain(win, tl, br, current_colour)


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        colour_count = not colour_count
        for X in range(0, window_size, 100):
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[0]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[1]
                else:
                    current_colour = colours[2]
                patch_plain(win, tl, br, current_colour)


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        colour_count = not colour_count
        for X in range(0, window_size, 100):
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                patch_plain(win, tl, br, current_colour)


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = not colour_count
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                patch_plain(win, tl, br, current_colour)


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 67
#      64     colours, size = get_inputs()
#      65     draw_patches(colours, size)
# ---> 67 main()
#      70 def draw_patch_window():
#      71     win = Window("Patch Design",500,500)
#
# Cell In[4], line 65, in main()
#      63 def main():
#      64     colours, size = get_inputs()
# ---> 65     draw_patches(colours, size)
#
# Cell In[4], line 29, in draw_patches(colours, size)
#      27 win = Window("Patch", window_size, window_size)
#      28 for Y in range(0, window_size, 100):
# ---> 29     colour_count = not colour_count
#      30     for X in range(0, window_size, 100):
#      31         colour_count = not colour_count
#
# UnboundLocalError: cannot access local variable 'colour_count' where it is not associated with a value

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    colour_count = True
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                patch_plain(win, tl, br, current_colour)


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                patch_plain(win, tl, br, current_colour)


def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_1(win, tl, br, current_colour)
                elif X < window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    pass

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_1(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    bg_colour = True
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if bg_colour == False:
                current_colour = "White"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    bg_colour = True
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            if bg_colour == False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
#   Cell In[2], line 28
#     def patch_1(win, tl, br, current_colour):
#                                              ^
# IndentationError: expected an indented block after 'if' statement on line 25

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    bg_colour = True
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            if bg_colour == False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass
            

def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    bg_colour = True
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            if bg_colour == False:
                current_colour = "null"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    bg_colour = True
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            if bg_colour == False:
                current_colour = False
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, "White")
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = True
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            colour_flipper = not colour_flipper
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = True
    for Y in range(0,100,25):
        h_flip = True
        colour_flipper = not colour_flipper
        for X in range(0,100,25):
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = True
    for Y in range(0,100,25):
        h_flip = True
        colour_flipper = not colour_flipper
        for X in range(0,100,25):
            colour_flipper = not colour_flipper
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        h_flip = True
        colour_flipper = not colour_flipper
        for X in range(0,100,25):
            colour_flipper = not colour_flipper
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            colour_flipper = not colour_flipper
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                pass


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            colour_flipper = not colour_flipper
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flipper = not colour_flipper


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            if colour_flipper:
                current_colour = "white"
            else:
                print("yay")
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flipper = not colour_flipper


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay
# yay

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        h_flip = True
        for X in range(0,100,25):
            if colour_flipper:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flipper = not colour_flipper


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if colour_flipper == False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flipper = not colour_flipper


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if colour_flipper is False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flipper = not colour_flipper


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flipper = False
    for Y in range(0,100,25):
        for X in range(0,100,25):
            colour_flipper = not colour_flipper
            if colour_flipper is False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flipper = not colour_flipper


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour, colour_flip):
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    colour_flip = True
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                colour_flip = not colour_flip
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour, colour_flip)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flip = not colour_flip
            print(colour_flip)


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True
# False
# True

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                pass
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_store = "white"
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white
# Flip:False Colour:white
# Flip:True Colour:white

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
                draw_rectangle(win, Point(tl.x,tl.y-1), br, current_colour)
                draw_rectangle(win, Point(tl.x-4,tl.y-2), br, current_colour)
                

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x,tl.y-1), br, current_colour)
                draw_rectangle(win, Point(tl.x-4,tl.y-2), br, current_colour)
                

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry

def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
                
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point(tl.x+(X-1),tl.y+(Y-1)), br, current_colour)
            else:
                pass
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point(tl.x+(X-5),tl.y+(Y-5)), br, current_colour)
            else:
                pass
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point(tl.x+(X-5),tl.y+(Y-5)), br, colour_store)
            else:
                pass
            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                draw_rectangle(win, Point(tl.x+(X-1),tl.y+(Y+1)), br, colour_store)
            else:
                pass

            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                draw_rectangle(win, Point((tl.x-1)+X,(tl.y-2)+Y), br, colour_store)
            else:
                pass

            colour_flip = not colour_flip
            print(f"Flip:{colour_flip} Colour:{current_colour}")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:True Colour:white
# Flip:False Colour:red
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue
# Flip:True Colour:white
# Flip:False Colour:blue

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            if h_flip:
                draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            #if h_flip:
            #    draw_rectangle(win, Point((tl.x-1)+X,(tl.y-2)+Y), br, colour_store)
            #else:
            #    pass

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)-5,(tl.y+Y)-5), br, current_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)-20,(tl.y+Y)-20), br, current_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)-20,(tl.y+Y)-20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            h_flip = not h_flip
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            h_flip = not h_flip
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            h_flip = not h_flip
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            h_flip = not h_flip
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            else:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, current_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    h_flip = True
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            h_flip = not h_flip
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "yellow")
            else:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "blue")
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    h_flip = True
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            h_flip = not h_flip
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "yellow")
            else:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "blue")
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    h_flip = True
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            h_flip = not h_flip

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "yellow")
            else:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "blue")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    h_flip = True
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "yellow")
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "blue")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    h_flip = True
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_flip)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_flip)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# GraphixError                              Traceback (most recent call last)
# Cell In[1], line 92
#      89     colours, size = get_inputs()
#      90     draw_patches(colours, size)
# ---> 92 main()
#      95 def draw_patch_window():
#      96     win = Window("Patch Design",500,500)
#
# Cell In[1], line 90, in main()
#      88 def main():
#      89     colours, size = get_inputs()
# ---> 90     draw_patches(colours, size)
#
# Cell In[1], line 73, in draw_patches(colours, size)
#      71     patch_plain(win, tl, br, current_colour)
#      72 else:
# ---> 73     patch_2(win, tl, br, current_colour)
#
# Cell In[1], line 33, in patch_2(win, tl, br, current_colour)
#      30     current_colour = colour_store
#      32 draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
# ---> 33 draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_flip)
#      34 draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_flip)
#      36 colour_flip = not colour_flip
#
# Cell In[1], line 7, in draw_rectangle(win, point1, point2, colour)
#       5 def draw_rectangle(win, point1, point2, colour):
#       6     rect = Rectangle(point1, point2)
# ----> 7     rect.fill_colour = colour
#       8     rect.draw(win)
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:351, in GraphixObject.fill_colour(self, colour)
#     348 @fill_colour.setter
#     349 def fill_colour(self, colour) -> None:
#     350     if not isinstance(colour, str):
# --> 351         raise GraphixError("Fill colour must be a string")
#     352     self._reconfig("fill", colour)
#
# GraphixError: Fill colour must be a string

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
#   Cell In[2], line 32
#     draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store
#                   ^
# SyntaxError: '(' was never closed

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = "white"
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = True
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = True
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                colour_store = current_colour
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)


            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)


            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = True
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is True:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                colour_store = current_colour
            else:
                current_colour = colour_store
                colour_store = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is True:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_flip)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# GraphixError                              Traceback (most recent call last)
# Cell In[1], line 91
#      88     colours, size = get_inputs()
#      89     draw_patches(colours, size)
# ---> 91 main()
#      94 def draw_patch_window():
#      95     win = Window("Patch Design",500,500)
#
# Cell In[1], line 89, in main()
#      87 def main():
#      88     colours, size = get_inputs()
# ---> 89     draw_patches(colours, size)
#
# Cell In[1], line 72, in draw_patches(colours, size)
#      70     patch_plain(win, tl, br, current_colour)
#      71 else:
# ---> 72     patch_2(win, tl, br, current_colour)
#
# Cell In[1], line 32, in patch_2(win, tl, br, current_colour)
#      29     current_colour = colour_store
#      31 draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
# ---> 32 draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_flip)
#      33 draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
#      35 colour_flip = not colour_flip
#
# Cell In[1], line 7, in draw_rectangle(win, point1, point2, colour)
#       5 def draw_rectangle(win, point1, point2, colour):
#       6     rect = Rectangle(point1, point2)
# ----> 7     rect.fill_colour = colour
#       8     rect.draw(win)
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:351, in GraphixObject.fill_colour(self, colour)
#     348 @fill_colour.setter
#     349 def fill_colour(self, colour) -> None:
#     350     if not isinstance(colour, str):
# --> 351         raise GraphixError("Fill colour must be a string")
#     352     self._reconfig("fill", colour)
#
# GraphixError: Fill colour must be a string

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    #colour_flip if for the current colour shown
    colour_flip = True
    #h_flip is for the H flip for the cubes.
    #Colour store keeps previous colour.
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                colour_store = current_colour
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 88
#      85     colours, size = get_inputs()
#      86     draw_patches(colours, size)
# ---> 88 main()
#      91 def draw_patch_window():
#      92     win = Window("Patch Design",500,500)
#
# Cell In[1], line 86, in main()
#      84 def main():
#      85     colours, size = get_inputs()
# ---> 86     draw_patches(colours, size)
#
# Cell In[1], line 69, in draw_patches(colours, size)
#      67     patch_plain(win, tl, br, current_colour)
#      68 else:
# ---> 69     patch_2(win, tl, br, current_colour)
#
# Cell In[1], line 25, in patch_2(win, tl, br, current_colour)
#      23     colour_store = current_colour
#      24 else:
# ---> 25     current_colour = colour_store
#      26     colour_store = "white"
#      28 draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
#
# UnboundLocalError: cannot access local variable 'colour_store' where it is not associated with a value

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                colour_store = current_colour
            else:
                current_colour = colour_store
                colour_store = "white"

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):

            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store

            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, colour_store)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "red")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "red")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "red")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = current_colour
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 86
#      83     colours, size = get_inputs()
#      84     draw_patches(colours, size)
# ---> 86 main()
#      89 def draw_patch_window():
#      90     win = Window("Patch Design",500,500)
#
# Cell In[2], line 84, in main()
#      82 def main():
#      83     colours, size = get_inputs()
# ---> 84     draw_patches(colours, size)
#
# Cell In[2], line 67, in draw_patches(colours, size)
#      65     patch_plain(win, tl, br, current_colour)
#      66 else:
# ---> 67     patch_2(win, tl, br, current_colour)
#
# Cell In[2], line 28, in patch_2(win, tl, br, current_colour)
#      25     current_colour = current_colour
#      27 draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
# ---> 28 draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, flipped_colour)
#      30 colour_flip = not colour_flip
#
# NameError: name 'flipped_colour' is not defined

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = current_colour
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "red")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "red")

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    colour_store = current_colour
    for Y in range(0,100,25):

        if Y >= 50:
            colour_flip = False

        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, "red")


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):

    colour_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):

        if Y >= 50:
            colour_flip = False
            
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):

    colour_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):

        if Y >= 50:
            colour_flip = False
            
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+16,(tl.y+Y)+4), br, flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+20), br, flipped_colour)
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), br, flipped_colour)
            else:
                pass
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)-5), br, flipped_colour)
            else:
                pass
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), br, flipped_colour)
            else:
                pass
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x+5,br.y+5), flipped_colour)
            else:
                pass
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)
            else:
                pass
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)
            else:
                pass
            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)

            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)
# Out:
#   Cell In[1], line 34
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 33

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)

            h_flip = not h_flip
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-10,br.y-10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+10), Point(br.x-25,br.y-25), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+10), Point(br.x,br.y+5), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+10), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+15), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+10,(tl.y+Y)+10), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+10), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+20,(tl.y+Y)+10), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+15), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x,br.y+10), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x-5,br.y-5), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x,br.y+5), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(br.x+5,br.y+5), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(((br.x+X)+5),((br.y+Y)+5)), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(((br.x+X)+10),((br.y+Y)+5)), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(((br.x+X)+10),((br.y+Y)+5)), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point(((br.x+X)-10),((br.y+Y)-5)), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+25), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+20,(tl.y+Y)+20), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)

            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)

            if h_flip:
                pass
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+20), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+15,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+5), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi!")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    #colour_one = input("Colour 1: ")
    colour_one = "blue"
    #colour_two = input("Colour 2: ")
    colour_two = "orange"
    #colour_three = input("Colour 3: ")
    colour_three = "red"
    colours = [colour_one, colour_two, colour_three]
    #chalange = input("If you'd like to edit the patch after, please enter Y: ")
    return colours, size


def main():
    colours, size = get_inputs()
    draw_patches(colours, size)

main()


def draw_patch_window():
    win = Window("Patch Design",500,500)
    SCREEN = 500
    TILE = 100
    for Y in range(0, SCREEN, TILE):
        for X in range(0, SCREEN, TILE):
            tl = Point(X,Y)
            br = Point(X + TILE, Y + TILE)
            #draw_rectangle(win, tl, br, "lime")
            message = Text(Point(int(X+50),int(Y+50)), "Brat")
            message.draw(win)

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100:
                    patch_1(win, tl, br, current_colour)
                elif X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100:
                    patch_plain(win, tl, br, current_colour)
                elif Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter Y: ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter Y: ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(win, Point(tl.x+X,tl.y+Y), br, "white")
            rect.outline_colour = current_colour
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 99
#      96     if edit:
#      97         edit_patch()
# ---> 99 main()
#
# Cell In[1], line 95, in main()
#      93 def main():
#      94     colours, size, edit = get_inputs()
# ---> 95     draw_patches(colours, size)
#      96     if edit:
#      97         edit_patch()
#
# Cell In[1], line 63, in draw_patches(colours, size)
#      61 current_colour = colours[1]
#      62 if Y < 100 or X > window_size - 200:
# ---> 63     patch_1(win, tl, br, current_colour)
#      64 else:
#      65     patch_plain(win, tl, br, current_colour)
#
# Cell In[1], line 44, in patch_1(win, tl, br, current_colour)
#      42 for Y in range(0,100,20):
#      43     for X in range(0,100,20):
# ---> 44         rect = Rectangle(win, Point(tl.x+X,tl.y+Y), br, "white")
#      45         rect.outline_colour = current_colour
#      46         message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
#
# TypeError: Rectangle.__init__() takes 3 positional arguments but 5 were given

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(win, Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 99
#      96     if edit:
#      97         edit_patch()
# ---> 99 main()
#
# Cell In[2], line 95, in main()
#      93 def main():
#      94     colours, size, edit = get_inputs()
# ---> 95     draw_patches(colours, size)
#      96     if edit:
#      97         edit_patch()
#
# Cell In[2], line 63, in draw_patches(colours, size)
#      61 current_colour = colours[1]
#      62 if Y < 100 or X > window_size - 200:
# ---> 63     patch_1(win, tl, br, current_colour)
#      64 else:
#      65     patch_plain(win, tl, br, current_colour)
#
# Cell In[2], line 44, in patch_1(win, tl, br, current_colour)
#      42 for Y in range(0,100,20):
#      43     for X in range(0,100,20):
# ---> 44         rect = Rectangle(win, Point(tl.x+X,tl.y+Y), br)
#      45         rect.outline_colour = current_colour
#      46         message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
#
# TypeError: Rectangle.__init__() takes 3 positional arguments but 4 were given

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(win, (Point(tl.x+X,tl.y+Y)), br)
            rect.outline_colour = current_colour
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[3], line 99
#      96     if edit:
#      97         edit_patch()
# ---> 99 main()
#
# Cell In[3], line 95, in main()
#      93 def main():
#      94     colours, size, edit = get_inputs()
# ---> 95     draw_patches(colours, size)
#      96     if edit:
#      97         edit_patch()
#
# Cell In[3], line 72, in draw_patches(colours, size)
#      70     current_colour = colours[2]
#      71 if X < 100 or Y > window_size - 200:
# ---> 72     patch_plain(win, tl, br, current_colour)
#      73 else:
#      74     patch_2(win, tl, br, current_colour)
#
# Cell In[3], line 13, in patch_plain(win, tl, br, colour)
#      11 rect = Rectangle(tl, br)
#      12 rect.fill_colour = colour
# ---> 13 rect.draw(win)
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:387, in GraphixObject.draw(self, window)
#     385     raise GraphixError("Can't draw to closed window")
#     386 self._canvas = window  # type: ignore
# --> 387 self._id = self._draw(window, self._config)
#     388 window._add_item(self)
#     389 if window._autoflush:
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:554, in Rectangle._draw(self, canvas, options)
#     552 x1,y1 = p1.x,p1.y
#     553 x2,y2 = p2.x,p2.y
# --> 554 return canvas.create_rectangle(x1,y1,x2,y2,options)
#
# File /usr/lib/python3.12/tkinter/__init__.py:2891, in Canvas.create_rectangle(self, *args, **kw)
#    2889 def create_rectangle(self, *args, **kw):
#    2890     """Create rectangle with coordinates x1,y1,x2,y2."""
# -> 2891     return self._create('rectangle', args, kw)
#
# File /usr/lib/python3.12/tkinter/__init__.py:2861, in Canvas._create(self, itemType, args, kw)
#    2859 else:
#    2860     cnf = {}
# -> 2861 return self.tk.getint(self.tk.call(
#    2862     self._w, 'create', itemType,
#    2863     *(args + self._options(cnf, kw))))
#
# TclError: unknown color name "re"

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(win, (Point(tl.x+X,tl.y+Y)), br)
            rect.outline_colour = current_colour
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            
            message.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 99
#      96     if edit:
#      97         edit_patch()
# ---> 99 main()
#
# Cell In[4], line 95, in main()
#      93 def main():
#      94     colours, size, edit = get_inputs()
# ---> 95     draw_patches(colours, size)
#      96     if edit:
#      97         edit_patch()
#
# Cell In[4], line 63, in draw_patches(colours, size)
#      61 current_colour = colours[1]
#      62 if Y < 100 or X > window_size - 200:
# ---> 63     patch_1(win, tl, br, current_colour)
#      64 else:
#      65     patch_plain(win, tl, br, current_colour)
#
# Cell In[4], line 44, in patch_1(win, tl, br, current_colour)
#      42 for Y in range(0,100,20):
#      43     for X in range(0,100,20):
# ---> 44         rect = Rectangle(win, (Point(tl.x+X,tl.y+Y)), br)
#      45         rect.outline_colour = current_colour
#      46         message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
#
# TypeError: Rectangle.__init__() takes 3 positional arguments but 4 were given

# %%
from graphix import Window, Point, Circle, Line, Rectangle, \
                    Polygon, Text, Entry


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)

def patch_2(win, tl, br, current_colour):
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            if h_flip:
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
            else:
                draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
            colour_flip = not colour_flip


def patch_1(win, tl, br, current_colour):
    for Y in range(0,100,20):
        for X in range(0,100,20):
            #draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)

def meow ():
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)

def draw_patches(colours, size):
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch_1(win, tl, br, current_colour)
                else:
                    patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch_plain(win, tl, br, current_colour)
                else:
                    patch_2(win, tl, br, current_colour)

def edit_patch():
    pass

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit


def main():
    colours, size, edit = get_inputs()
    draw_patches(colours, size)
    if edit:
        edit_patch()

main()

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    patch = []
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    rect.append(patch)
    return patch

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch = []
        patch_dict["Patch ",counter] = patch
    return patch_dict

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)
    edit_patch(patch_dict)

main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 117
#     114     patch_dict = draw_patches(colours, size)
#     115     edit_patch(patch_dict)
# --> 117 main()
#
# Cell In[1], line 114, in main()
#     112 def main():
#     113     colours, size, edit = get_inputs()
# --> 114     patch_dict = draw_patches(colours, size)
#     115     edit_patch(patch_dict)
#
# Cell In[1], line 89, in draw_patches(colours, size)
#      87     current_colour = colours[2]
#      88 if X < 100 or Y > window_size - 200:
# ---> 89     patch = patch_plain(win, tl, br, current_colour)
#      90 else:
#      91     patch = patch_2(win, tl, br, current_colour)
#
# Cell In[1], line 16, in patch_plain(win, tl, br, colour)
#      14 rect.fill_colour = colour
#      15 rect.draw(win)
# ---> 16 rect.append(patch)
#      17 return patch
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:340, in GraphixObject.__getattr__(self, name)
#     339 def __getattr__(self, name) -> Any:
# --> 340     raise AttributeError(f"'{self.__class__.__name__}' "
#     341                          f"object has no attribute '{name}'")
#
# AttributeError: 'Rectangle' object has no attribute 'append'

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    patch = []
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    rect.append(patch)
    return patch

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    return patch_dict

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)
    edit_patch(patch_dict)

main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 116
#     113     patch_dict = draw_patches(colours, size)
#     114     edit_patch(patch_dict)
# --> 116 main()
#
# Cell In[1], line 113, in main()
#     111 def main():
#     112     colours, size, edit = get_inputs()
# --> 113     patch_dict = draw_patches(colours, size)
#     114     edit_patch(patch_dict)
#
# Cell In[1], line 89, in draw_patches(colours, size)
#      87     current_colour = colours[2]
#      88 if X < 100 or Y > window_size - 200:
# ---> 89     patch = patch_plain(win, tl, br, current_colour)
#      90 else:
#      91     patch = patch_2(win, tl, br, current_colour)
#
# Cell In[1], line 16, in patch_plain(win, tl, br, colour)
#      14 rect.fill_colour = colour
#      15 rect.draw(win)
# ---> 16 rect.append(patch)
#      17 return patch
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:340, in GraphixObject.__getattr__(self, name)
#     339 def __getattr__(self, name) -> Any:
# --> 340     raise AttributeError(f"'{self.__class__.__name__}' "
#     341                          f"object has no attribute '{name}'")
#
# AttributeError: 'Rectangle' object has no attribute 'append'

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    patch = []
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    rect.append(patch)
    return patch

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    return patch_dict

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)
    edit_patch(patch_dict)

main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 116
#     113     patch_dict = draw_patches(colours, size)
#     114     edit_patch(patch_dict)
# --> 116 main()
#
# Cell In[1], line 113, in main()
#     111 def main():
#     112     colours, size, edit = get_inputs()
# --> 113     patch_dict = draw_patches(colours, size)
#     114     edit_patch(patch_dict)
#
# Cell In[1], line 89, in draw_patches(colours, size)
#      87     current_colour = colours[2]
#      88 if X < 100 or Y > window_size - 200:
# ---> 89     patch = patch_plain(win, tl, br, current_colour)
#      90 else:
#      91     patch = patch_2(win, tl, br, current_colour)
#
# Cell In[1], line 16, in patch_plain(win, tl, br, colour)
#      14 rect.fill_colour = colour
#      15 rect.draw(win)
# ---> 16 rect.append(patch)
#      17 return patch
#
# File ~/Course/programming/Course-Work/assign1/graphix.py:340, in GraphixObject.__getattr__(self, name)
#     339 def __getattr__(self, name) -> Any:
# --> 340     raise AttributeError(f"'{self.__class__.__name__}' "
#     341                          f"object has no attribute '{name}'")
#
# AttributeError: 'Rectangle' object has no attribute 'append'

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    return patch_dict

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)
    edit_patch(patch_dict)

main()
# Out:
# {(400, 0): [Rectangle(Point(400, 0), Point(500, 100)), Text(Point(410, 10), 'Hi'), Rectangle(Point(420, 0), Point(500, 100)), Text(Point(430, 10), 'Hi'), Rectangle(Point(440, 0), Point(500, 100)), Text(Point(450, 10), 'Hi'), Rectangle(Point(460, 0), Point(500, 100)), Text(Point(470, 10), 'Hi'), Rectangle(Point(480, 0), Point(500, 100)), Text(Point(490, 10), 'Hi'), Rectangle(Point(400, 20), Point(500, 100)), Text(Point(410, 30), 'Hi'), Rectangle(Point(420, 20), Point(500, 100)), Text(Point(430, 30), 'Hi'), Rectangle(Point(440, 20), Point(500, 100)), Text(Point(450, 30), 'Hi'), Rectangle(Point(460, 20), Point(500, 100)), Text(Point(470, 30), 'Hi'), Rectangle(Point(480, 20), Point(500, 100)), Text(Point(490, 30), 'Hi'), Rectangle(Point(400, 40), Point(500, 100)), Text(Point(410, 50), 'Hi'), Rectangle(Point(420, 40), Point(500, 100)), Text(Point(430, 50), 'Hi'), Rectangle(Point(440, 40), Point(500, 100)), Text(Point(450, 50), 'Hi'), Rectangle(Point(460, 40), Point(500, 100)), Text(Point(470, 50), 'Hi'), Rectangle(Point(480, 40), Point(500, 100)), Text(Point(490, 50), 'Hi'), Rectangle(Point(400, 60), Point(500, 100)), Text(Point(410, 70), 'Hi'), Rectangle(Point(420, 60), Point(500, 100)), Text(Point(430, 70), 'Hi'), Rectangle(Point(440, 60), Point(500, 100)), Text(Point(450, 70), 'Hi'), Rectangle(Point(460, 60), Point(500, 100)), Text(Point(470, 70), 'Hi'), Rectangle(Point(480, 60), Point(500, 100)), Text(Point(490, 70), 'Hi'), Rectangle(Point(400, 80), Point(500, 100)), Text(Point(410, 90), 'Hi'), Rectangle(Point(420, 80), Point(500, 100)), Text(Point(430, 90), 'Hi'), Rectangle(Point(440, 80), Point(500, 100)), Text(Point(450, 90), 'Hi'), Rectangle(Point(460, 80), Point(500, 100)), Text(Point(470, 90), 'Hi'), Rectangle(Point(480, 80), Point(500, 100)), Text(Point(490, 90), 'Hi')], (400, 100): [Rectangle(Point(400, 100), Point(500, 200)), Text(Point(410, 110), 'Hi'), Rectangle(Point(420, 100), Point(500, 200)), Text(Point(430, 110), 'Hi'), Rectangle(Point(440, 100), Point(500, 200)), Text(Point(450, 110), 'Hi'), Rectangle(Point(460, 100), Point(500, 200)), Text(Point(470, 110), 'Hi'), Rectangle(Point(480, 100), Point(500, 200)), Text(Point(490, 110), 'Hi'), Rectangle(Point(400, 120), Point(500, 200)), Text(Point(410, 130), 'Hi'), Rectangle(Point(420, 120), Point(500, 200)), Text(Point(430, 130), 'Hi'), Rectangle(Point(440, 120), Point(500, 200)), Text(Point(450, 130), 'Hi'), Rectangle(Point(460, 120), Point(500, 200)), Text(Point(470, 130), 'Hi'), Rectangle(Point(480, 120), Point(500, 200)), Text(Point(490, 130), 'Hi'), Rectangle(Point(400, 140), Point(500, 200)), Text(Point(410, 150), 'Hi'), Rectangle(Point(420, 140), Point(500, 200)), Text(Point(430, 150), 'Hi'), Rectangle(Point(440, 140), Point(500, 200)), Text(Point(450, 150), 'Hi'), Rectangle(Point(460, 140), Point(500, 200)), Text(Point(470, 150), 'Hi'), Rectangle(Point(480, 140), Point(500, 200)), Text(Point(490, 150), 'Hi'), Rectangle(Point(400, 160), Point(500, 200)), Text(Point(410, 170), 'Hi'), Rectangle(Point(420, 160), Point(500, 200)), Text(Point(430, 170), 'Hi'), Rectangle(Point(440, 160), Point(500, 200)), Text(Point(450, 170), 'Hi'), Rectangle(Point(460, 160), Point(500, 200)), Text(Point(470, 170), 'Hi'), Rectangle(Point(480, 160), Point(500, 200)), Text(Point(490, 170), 'Hi'), Rectangle(Point(400, 180), Point(500, 200)), Text(Point(410, 190), 'Hi'), Rectangle(Point(420, 180), Point(500, 200)), Text(Point(430, 190), 'Hi'), Rectangle(Point(440, 180), Point(500, 200)), Text(Point(450, 190), 'Hi'), Rectangle(Point(460, 180), Point(500, 200)), Text(Point(470, 190), 'Hi'), Rectangle(Point(480, 180), Point(500, 200)), Text(Point(490, 190), 'Hi')], (400, 200): [Rectangle(Point(400, 200), Point(500, 300)), Text(Point(410, 210), 'Hi'), Rectangle(Point(420, 200), Point(500, 300)), Text(Point(430, 210), 'Hi'), Rectangle(Point(440, 200), Point(500, 300)), Text(Point(450, 210), 'Hi'), Rectangle(Point(460, 200), Point(500, 300)), Text(Point(470, 210), 'Hi'), Rectangle(Point(480 ...

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    return patch_dict

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)
    while True:
        click = win.get_mouse()
        patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100

        delete_patch_group(grid_objects[(patch_x, patch_y)])
        grid_objects.pop((patch_x, patch_y))

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 119
#     116         delete_patch_group(grid_objects[(patch_x, patch_y)])
#     117         grid_objects.pop((patch_x, patch_y))
# --> 119 main()
#
# Cell In[1], line 113, in main()
#     111 patch_dict = draw_patches(colours, size)
#     112 while True:
# --> 113     click = win.get_mouse()
#     114     patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100
#     116     delete_patch_group(grid_objects[(patch_x, patch_y)])
#
# NameError: name 'win' is not defined

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    while True:
        click = win.get_mouse()
        patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100

        delete_patch_group(grid_objects[(patch_x, patch_y)])
        grid_objects.pop((patch_x, patch_y))
    return patch_dict

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)


main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 120
#     116     colours, size, edit = get_inputs()
#     117     patch_dict = draw_patches(colours, size)
# --> 120 main()
#
# Cell In[1], line 117, in main()
#     115 def main():
#     116     colours, size, edit = get_inputs()
# --> 117     patch_dict = draw_patches(colours, size)
#
# Cell In[1], line 95, in draw_patches(colours, size)
#      92     click = win.get_mouse()
#      93     patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100
# ---> 95     delete_patch_group(grid_objects[(patch_x, patch_y)])
#      96     grid_objects.pop((patch_x, patch_y))
#      97 return patch_dict
#
# NameError: name 'delete_patch_group' is not defined

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    while True:
        click = win.get_mouse()
        patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100

        delete_patch_group(patch_dict[(patch_x, patch_y)])
        patch_dict.pop((patch_x, patch_y))
    return patch_dict

def delete_patch_group(patch_objects):
    for obj in patch_objects:
        obj.undraw()

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)


main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 124
#     120     colours, size, edit = get_inputs()
#     121     patch_dict = draw_patches(colours, size)
# --> 124 main()
#
# Cell In[2], line 121, in main()
#     119 def main():
#     120     colours, size, edit = get_inputs()
# --> 121     patch_dict = draw_patches(colours, size)
#
# Cell In[2], line 95, in draw_patches(colours, size)
#      92     click = win.get_mouse()
#      93     patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100
# ---> 95     delete_patch_group(patch_dict[(patch_x, patch_y)])
#      96     patch_dict.pop((patch_x, patch_y))
#      97 return patch_dict
#
# KeyError: (100, 100)

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    while True:
        click = win.get_mouse()
        patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100

        delete_patch_group(patch_dict[(patch_x, patch_y)])
        patch_dict.pop((patch_x, patch_y))
    return patch_dict

def delete_patch_group(patch_objects):
    for obj in patch_objects:
        obj.undraw()

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)


main()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 124
#     120     colours, size, edit = get_inputs()
#     121     patch_dict = draw_patches(colours, size)
# --> 124 main()
#
# Cell In[3], line 121, in main()
#     119 def main():
#     120     colours, size, edit = get_inputs()
# --> 121     patch_dict = draw_patches(colours, size)
#
# Cell In[3], line 95, in draw_patches(colours, size)
#      92     click = win.get_mouse()
#      93     patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100
# ---> 95     delete_patch_group(patch_dict[(patch_x, patch_y)])
#      96     patch_dict.pop((patch_x, patch_y))
#      97 return patch_dict
#
# KeyError: (0, 0)

# %%
"""Grathix Module use"""
from graphix import Window, Point, Rectangle, Text


def draw_rectangle(win, point1, point2, colour):
    rect = Rectangle(point1, point2)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_plain(win, tl, br, colour):
    rect = Rectangle(tl, br)
    rect.fill_colour = colour
    rect.draw(win)
    return rect

def patch_2(win, tl, br, current_colour):
    patch = []
    colour_flip = True
    h_flip = True
    colour_store = current_colour
    flipped_colour = ""
    for Y in range(0,100,25):
        h_flip = not h_flip
        if Y >= 50:
            colour_flip = False
        for X in range(0,100,25):
            if colour_flip is False:
                current_colour = "white"
                flipped_colour = colour_store
            else:
                current_colour = colour_store
                flipped_colour = "white"
            rect = draw_rectangle(win, Point(tl.x+X,tl.y+Y), br, current_colour)
            patch.append(rect)
            if h_flip:
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)+25), Point((tl.x+X)+20,(tl.y+Y)+15), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X)+5,(tl.y+Y)), Point((tl.x+X)+20,(tl.y+Y)+10), flipped_colour)
                patch.append(rect)
            else:
                rect = draw_rectangle(win, Point((tl.x+X)+15,(tl.y+Y)+5), Point((tl.x+X)+25,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
                rect = draw_rectangle(win, Point((tl.x+X),(tl.y+Y)+5), Point((tl.x+X)+10,(tl.y+Y)+20), flipped_colour)
                patch.append(rect)
            colour_flip = not colour_flip
    return patch 

def patch_1(win, tl, br, current_colour):
    patch = []
    for Y in range(0,100,20):
        for X in range(0,100,20):
            rect = Rectangle(Point(tl.x+X,tl.y+Y), br)
            rect.outline_colour = current_colour
            rect.draw(win)
            patch.append(rect)
            message = Text(Point(tl.x+(X+10),tl.y+(Y+10)), "Hi")
            message.text_colour = current_colour
            message.draw(win)
            patch.append(message)
    return patch

def draw_patches(colours, size):
    patch_dict = {}
    window_size = size * 100
    win = Window("Patch", window_size, window_size)
    counter = 0
    for Y in range(0, window_size, 100):
        colour_count = True
        for X in range(0, window_size, 100):
            counter = counter + 1
            colour_count = not colour_count
            tl = Point(X,Y)
            br = Point(X + 100, Y + 100)
            if X > Y:
                current_colour = colours[1]
                if Y < 100 or X > window_size - 200:
                    patch = patch_1(win, tl, br, current_colour)
                else:
                    patch = patch_plain(win, tl, br, current_colour)
            else:
                if colour_count:
                    current_colour = colours[0]
                else:
                    current_colour = colours[2]
                if X < 100 or Y > window_size - 200:
                    patch = patch_plain(win, tl, br, current_colour)
                else:
                    patch = patch_2(win, tl, br, current_colour)
        patch_dict[(X,Y)] = patch
    print(patch_dict)
    while True:
        click = win.get_mouse()
        patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100
        delete_patch_group(patch_dict[(patch_x, patch_y)])
        patch_dict.pop((patch_x, patch_y))

def delete_patch_group(patch_objects):
    for obj in patch_objects:
        obj.undraw()

def edit_patch(patch_dict):
    print(patch_dict)

def get_inputs():
    size = int(input("Please enter what size you'd like (5, 7, 9): "))
    colour_one = input("Colour 1: ")
    colour_two = input("Colour 2: ")
    colour_three = input("Colour 3: ")
    colours = [colour_one, colour_two, colour_three]
    edit = input("If you'd like to edit the patch after, please enter 'Y': ")
    if edit == "Y":
        edit = True
    else: 
        edit = False
    return colours, size, edit

def main():
    colours, size, edit = get_inputs()
    patch_dict = draw_patches(colours, size)


main()
# Out:
# {(400, 0): [Rectangle(Point(400, 0), Point(500, 100)), Text(Point(410, 10), 'Hi'), Rectangle(Point(420, 0), Point(500, 100)), Text(Point(430, 10), 'Hi'), Rectangle(Point(440, 0), Point(500, 100)), Text(Point(450, 10), 'Hi'), Rectangle(Point(460, 0), Point(500, 100)), Text(Point(470, 10), 'Hi'), Rectangle(Point(480, 0), Point(500, 100)), Text(Point(490, 10), 'Hi'), Rectangle(Point(400, 20), Point(500, 100)), Text(Point(410, 30), 'Hi'), Rectangle(Point(420, 20), Point(500, 100)), Text(Point(430, 30), 'Hi'), Rectangle(Point(440, 20), Point(500, 100)), Text(Point(450, 30), 'Hi'), Rectangle(Point(460, 20), Point(500, 100)), Text(Point(470, 30), 'Hi'), Rectangle(Point(480, 20), Point(500, 100)), Text(Point(490, 30), 'Hi'), Rectangle(Point(400, 40), Point(500, 100)), Text(Point(410, 50), 'Hi'), Rectangle(Point(420, 40), Point(500, 100)), Text(Point(430, 50), 'Hi'), Rectangle(Point(440, 40), Point(500, 100)), Text(Point(450, 50), 'Hi'), Rectangle(Point(460, 40), Point(500, 100)), Text(Point(470, 50), 'Hi'), Rectangle(Point(480, 40), Point(500, 100)), Text(Point(490, 50), 'Hi'), Rectangle(Point(400, 60), Point(500, 100)), Text(Point(410, 70), 'Hi'), Rectangle(Point(420, 60), Point(500, 100)), Text(Point(430, 70), 'Hi'), Rectangle(Point(440, 60), Point(500, 100)), Text(Point(450, 70), 'Hi'), Rectangle(Point(460, 60), Point(500, 100)), Text(Point(470, 70), 'Hi'), Rectangle(Point(480, 60), Point(500, 100)), Text(Point(490, 70), 'Hi'), Rectangle(Point(400, 80), Point(500, 100)), Text(Point(410, 90), 'Hi'), Rectangle(Point(420, 80), Point(500, 100)), Text(Point(430, 90), 'Hi'), Rectangle(Point(440, 80), Point(500, 100)), Text(Point(450, 90), 'Hi'), Rectangle(Point(460, 80), Point(500, 100)), Text(Point(470, 90), 'Hi'), Rectangle(Point(480, 80), Point(500, 100)), Text(Point(490, 90), 'Hi')], (400, 100): [Rectangle(Point(400, 100), Point(500, 200)), Text(Point(410, 110), 'Hi'), Rectangle(Point(420, 100), Point(500, 200)), Text(Point(430, 110), 'Hi'), Rectangle(Point(440, 100), Point(500, 200)), Text(Point(450, 110), 'Hi'), Rectangle(Point(460, 100), Point(500, 200)), Text(Point(470, 110), 'Hi'), Rectangle(Point(480, 100), Point(500, 200)), Text(Point(490, 110), 'Hi'), Rectangle(Point(400, 120), Point(500, 200)), Text(Point(410, 130), 'Hi'), Rectangle(Point(420, 120), Point(500, 200)), Text(Point(430, 130), 'Hi'), Rectangle(Point(440, 120), Point(500, 200)), Text(Point(450, 130), 'Hi'), Rectangle(Point(460, 120), Point(500, 200)), Text(Point(470, 130), 'Hi'), Rectangle(Point(480, 120), Point(500, 200)), Text(Point(490, 130), 'Hi'), Rectangle(Point(400, 140), Point(500, 200)), Text(Point(410, 150), 'Hi'), Rectangle(Point(420, 140), Point(500, 200)), Text(Point(430, 150), 'Hi'), Rectangle(Point(440, 140), Point(500, 200)), Text(Point(450, 150), 'Hi'), Rectangle(Point(460, 140), Point(500, 200)), Text(Point(470, 150), 'Hi'), Rectangle(Point(480, 140), Point(500, 200)), Text(Point(490, 150), 'Hi'), Rectangle(Point(400, 160), Point(500, 200)), Text(Point(410, 170), 'Hi'), Rectangle(Point(420, 160), Point(500, 200)), Text(Point(430, 170), 'Hi'), Rectangle(Point(440, 160), Point(500, 200)), Text(Point(450, 170), 'Hi'), Rectangle(Point(460, 160), Point(500, 200)), Text(Point(470, 170), 'Hi'), Rectangle(Point(480, 160), Point(500, 200)), Text(Point(490, 170), 'Hi'), Rectangle(Point(400, 180), Point(500, 200)), Text(Point(410, 190), 'Hi'), Rectangle(Point(420, 180), Point(500, 200)), Text(Point(430, 190), 'Hi'), Rectangle(Point(440, 180), Point(500, 200)), Text(Point(450, 190), 'Hi'), Rectangle(Point(460, 180), Point(500, 200)), Text(Point(470, 190), 'Hi'), Rectangle(Point(480, 180), Point(500, 200)), Text(Point(490, 190), 'Hi')], (400, 200): [Rectangle(Point(400, 200), Point(500, 300)), Text(Point(410, 210), 'Hi'), Rectangle(Point(420, 200), Point(500, 300)), Text(Point(430, 210), 'Hi'), Rectangle(Point(440, 200), Point(500, 300)), Text(Point(450, 210), 'Hi'), Rectangle(Point(460, 200), Point(500, 300)), Text(Point(470, 210), 'Hi'), Rectangle(Point(480 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 123
#     119     colours, size, edit = get_inputs()
#     120     patch_dict = draw_patches(colours, size)
# --> 123 main()
#
# Cell In[1], line 120, in main()
#     118 def main():
#     119     colours, size, edit = get_inputs()
# --> 120     patch_dict = draw_patches(colours, size)
#
# Cell In[1], line 95, in draw_patches(colours, size)
#      93 click = win.get_mouse()
#      94 patch_x, patch_y = click.x // 100 * 100, click.y // 100 * 100
# ---> 95 delete_patch_group(patch_dict[(patch_x, patch_y)])
#      96 patch_dict.pop((patch_x, patch_y))
#
# KeyError: (200, 100)
